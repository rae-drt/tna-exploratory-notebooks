# %% [markdown]
# # Graphs, and the power of visualising datasets

# %% [markdown]
# ## Introduction
#
# In this pair of notebooks, we are going to show how drawing meaningful graphs of large datasets can highlight interesting features that might have otherwise been missed when looking line-by-line at the data. These two notebooks are intended as a starting point, showing examples of two fairly common graphs, with the goal that you can then apply the same techniques to your own data sets. The first of these two notebooks is going to gather a dataset from Discovery and manipulate it into pandas dataframe. The second notebook will then use the matplotlib library to draw the graphs.

# %% [markdown]
# As always, we need to start by importing and installing required libraries. Note that this time, we are also gathering some pre-defined data - these are a couple of lists we are going to use to automate the calls to discovery to gather the data. The list of ship names is based on a list of ships of the Royal Navy from the War of 1812. The list of record series are some pre-selected series to limit our requests to Discovery.

# %%
# %pip install -q pandas
# %pip install -q json
# %pip install -q requests

import pandas as pd
import json
import requests

import aditional_data

record_series = aditional_data.admiralty_record_series
ship_list = aditional_data.ships
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## What graphs are we going to draw?
#
# Discovery has a lot of metadata about each record available to use, so we are going to need to narrow things down a bit. For the purpose of these notebooks, we are going to take the position of a researcher into record descriptions - record description length can vary significantly (from a word to [several paragraphs](https://discovery.nationalarchives.gov.uk/browse/r/r/C10488311), within related records). As the description, along with the title, is one of the main ways a typical user would find a record, we are going to gather data and draw graphs to help illuminate the area.

# %% [markdown]
# ## Getting the data
#
# To get the data we need we are going to use the Discovery API, similar to the [main series of notebooks](../1-intro-to-discovery-api.ipynb). As we have previously gone into it in detail, we are going to do this in one cell. This cell is going to run through the lists we imported earlier, use their data to build a request to the `search` endpoint, and select only the data we need from the results. As we have previously decided that we are interested in record descriptions and covering dates, we are only going to keep fields relating to those.
#
# As this request is going take some time, it is worth considering how we want to structure the json we want to build from the response, to help ensure we get the right data first time. Given that we are going to be looping through a list of names of ships, and extracting data from each record in response, we are going to initially build a dictionary like this, which is structured in a way where we can see the result of each query:
#
# ```json
# [
#     {
#         "ship": "[ship name]",
#         "data": [
#             {
#                 "id": "[record id]",
#                 "title": "[record title]",
#                 "startDate": "[record start date]",
#                 "endDate": "[record end date]",
#                 "description": "[record description]",
#                 "reference": "[record reference]"
#             },
#             ...next record
#         ]
#     },
#     ...next ship
# ]
# ```
#
#  Note: with the length of the list of ship names, this cell makes a lot of requests to Discovery and can take a minute or two to run. Also note that as this is an example only, we're only retrieving the default number of records with each query; in a real world scenario, you would want to spend time refining the query to ensure you retrieve all intended records.

# %%
ship_data = []

base_discovery_url = "https://discovery.nationalarchives.gov.uk/API/search/records?"

for ship in ship_list:
    url = base_discovery_url 
    for series in record_series:
        url += series
        url += "&"
    url += "sps.searchQuery=" + ship
    # print(url)                        # uncomment this line to see the url being used
    headers = {'Accept': 'application/json'}
    response = requests.get(url, headers=headers)
    response_json = response.json()
    #print(response_json)               # if you want to see the full response to each query, uncomment this line
    if response_json["records"] != []:
        found_data = []
        for record in response_json["records"]:
            found_data.append(
                {
                    "id": record["id"],
                    "title": record["title"],
                    "startDate": record["startDate"],
                    "endDate": record["endDate"],
                    "description": record["description"],
                    "reference": record["reference"].split("/")[0] # here, we would normally get a reference such as ADM 1/1234, but we only want the ADM 1 part
                }
            )
        ship_data.append(
            {
                "ship": ship,
                "data": found_data
            }
        )
        
        
print(json.dumps(ship_data, indent=4))
# Out:
# [
#     {
#         "ship": "Acasta",
#         "data": [
#             {
#                 "id": "C1496956",
#                 "title": "ACASTA",
#                 "startDate": "01/09/1918",
#                 "endDate": "31/10/1918",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496944",
#                 "title": "ACASTA",
#                 "startDate": "08/02/1915",
#                 "endDate": "09/04/1915",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496952",
#                 "title": "ACASTA",
#                 "startDate": "01/11/1917",
#                 "endDate": "02/02/1918",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496951",
#                 "title": "ACASTA",
#                 "startDate": "01/05/1917",
#                 "endDate": "01/07/1917",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1480967",
#                 "title": "ACASTA",
#                 "startDate": "01/08/1913",
#                 "endDate": "30/09/1913",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496964",
#                 "title": "ACASTA",
#                 "startDate": "01/01/1920",
#                 "endDate": "29/02/1920",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1558828",
#                 "title": "ACASTA",
#                 "startDate": "01/10/1935",
#                 "endDate": "31/10/1935",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1558821",
#                 "title": "ACASTA",
#                 "startDate": "01/04/1935",
#                 "endDate": "30/04/1935",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1534181",
#                 "title": "ACASTA.",
#                 "startDate": "01/08/1934",
#                 "endDate": "31/08/1934",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1534134",
#                 "title": "ACASTA.",
#                 "startDate": "14/04/1930",
#                 "endDate": "14/06/1930",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1534164",
#                 "title": "ACASTA.",
#                 "startDate": "01/03/1933",
#                 "endDate": "31/03/1933",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1534151",
#                 "title": "ACASTA.",
#                 "startDate": "01/11/1931",
#                 "endDate": "30/11/1931",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1565169",
#                 "title": "ACASTA",
#                 "startDate": "01/04/1938",
#                 "endDate": "30/04/1938",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1565166",
#                 "title": "ACASTA",
#                 "startDate": "01/07/1937",
#                 "endDate": "31/07/1937",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1565162",
#                 "title": "ACASTA",
#                 "startDate": "01/03/1937",
#                 "endDate": "31/03/1937",
#                 "description": "ACASTA.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Aeolus",
#         "data": [
#             {
#                 "id": "C1481046",
#                 "title": "AEOLUS",
#                 "startDate": "09/06/1904",
#                 "endDate": "30/05/1905",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481050",
#                 "title": "AEOLUS",
#                 "startDate": "30/06/1908",
#                 "endDate": "01/08/1908",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481047",
#                 "title": "AEOLUS",
#                 "startDate": "31/05/1905",
#                 "endDate": "07/09/1905",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476643",
#                 "title": "AEOLUS",
#                 "startDate": "08/01/1895",
#                 "endDate": "31/12/1895",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476641",
#                 "title": "AEOLUS",
#                 "startDate": "11/07/1893",
#                 "endDate": "25/08/1893",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481044",
#                 "title": "AEOLUS",
#                 "startDate": "16/09/1902",
#                 "endDate": "18/06/1903",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481045",
#                 "title": "AEOLUS",
#                 "startDate": "19/06/1903",
#                 "endDate": "08/06/1904",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481049",
#                 "title": "AEOLUS",
#                 "startDate": "31/08/1906",
#                 "endDate": "31/05/1907",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481048",
#                 "title": "AEOLUS",
#                 "startDate": "08/09/1905",
#                 "endDate": "30/08/1906",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481053",
#                 "title": "AEOLUS",
#                 "startDate": "13/05/1912",
#                 "endDate": "30/04/1913",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476646",
#                 "title": "AEOLUS",
#                 "startDate": "15/06/1897",
#                 "endDate": "04/08/1897",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476642",
#                 "title": "AEOLUS",
#                 "startDate": "16/01/1894",
#                 "endDate": "07/01/1895",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481054",
#                 "title": "AEOLUS",
#                 "startDate": "01/05/1913",
#                 "endDate": "03/10/1913",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481043",
#                 "title": "AEOLUS",
#                 "startDate": "16/07/1901",
#                 "endDate": "20/08/1901",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481042",
#                 "title": "AEOLUS",
#                 "startDate": "11/07/1899",
#                 "endDate": "17/08/1899",
#                 "description": "AEOLUS.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Aetna",
#         "data": [
#             {
#                 "id": "C1464685",
#                 "title": "Aetna (Etna)",
#                 "startDate": "23/10/1834",
#                 "endDate": "31/12/1836",
#                 "description": "Aetna (Etna).",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1464686",
#                 "title": "Aetna (Etna)",
#                 "startDate": "01/01/1837",
#                 "endDate": "13/11/1838",
#                 "description": "Aetna (Etna).",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1464683",
#                 "title": "Aetna (Etna)",
#                 "startDate": "27/05/1830",
#                 "endDate": "10/09/1833",
#                 "description": "Aetna (Etna).",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1464687",
#                 "title": "Aetna (Etna)",
#                 "startDate": "08/02/1839",
#                 "endDate": "25/04/1842",
#                 "description": "Aetna (Etna).",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C6224063",
#                 "title": "Aetna (Etna)",
#                 "startDate": "11/06/1842",
#                 "endDate": "11/03/1844",
#                 "description": "Aetna (Etna).",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C6224062",
#                 "title": "Aetna (Etna)",
#                 "startDate": "12/12/1827",
#                 "endDate": "24/05/1830",
#                 "description": "Aetna (Etna).",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C16604172",
#                 "title": "Masters' logs: Aetna",
#                 "startDate": "15/03/1836",
#                 "endDate": "18/11/1838",
#                 "description": "Masters' logs: Aetna.",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2529962",
#                 "title": "Masters' logs, including: Aetna (1778 May 14 - 1779 Feb 26). Aetna (1779 Mar 4...",
#                 "startDate": "01/01/1778",
#                 "endDate": "31/12/1781",
#                 "description": "Masters' logs, including: Aetna (1778 May 14 - 1779 Feb 26). Aetna (1779 Mar 4 - 1779 Aug 29). Aetna (1780 Jan 17 - 1781 Mar 7). Aetna (1781 July 12 - 1781 Dec 5).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2529963",
#                 "title": "Masters' logs, including: Aetna (1804 Jan 4 - 1805 Jan 5). Aetna (1805 Jan 17...",
#                 "startDate": "01/01/1801",
#                 "endDate": "31/12/1806",
#                 "description": "Masters' logs, including: Aetna (1804 Jan 4 - 1805 Jan 5). Aetna (1805 Jan 17 - 1805 May 4). Aetna (1805 Sept 19 - 1806 July 22). Argo (1801 Sept 16 - 1804 Oct 27). Atalante (1803 Jan 14 - 1803 Dec 31). Atalante (1804 Jan 19 - 1805 Aug 21).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2529961",
#                 "title": "Masters' logs, including: Aetna (1756 Dec 16 - 1757 July 31). Aetna (1757 Aug 12...",
#                 "startDate": "01/01/1756",
#                 "endDate": "31/12/1758",
#                 "description": "Masters' logs, including: Aetna (1756 Dec 16 - 1757 July 31). Aetna (1757 Aug 12 - 1758 May 20).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2529959",
#                 "title": "Masters' logs, including: Aetna (1691/2 Feb 22 - 1693 Nov 25). Aetna (1695 June 8...",
#                 "startDate": "01/01/1690",
#                 "endDate": "31/12/1701",
#                 "description": "Masters' logs, including: Aetna (1691/2 Feb 22 - 1693 Nov 25). Aetna (1695 June 8 - 1696 June 27). Eagle (1689/90 Feb 13 - 1695 Nov 19). Eagle (1696 Sept 23 - 1697 Dec 7). Eagle (1697/8 Feb 2 - 1699 May 22). Eagle (1699/1700 Mar 11 - 1700/1 Feb 20).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C4458433",
#                 "title": "Captains' logs, including: AETNA (1831 Oct 27-1832 Apr 30). AETNA (1833 Jan 1-1833 Sept 10)....",
#                 "startDate": "01/01/1831",
#                 "endDate": "31/12/1836",
#                 "description": "Captains' logs, including: AETNA (1831 Oct 27-1832 Apr 30). AETNA (1833 Jan 1-1833 Sept 10). AETNA (1833 Dec 24-1836 Sept 30).",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C4458431",
#                 "title": "Captains' logs, including: AETNA (1824 May 8-1824 Oct 10). AETNA (1827 Dec 12-1830 Dec 31)...",
#                 "startDate": "01/01/1824",
#                 "endDate": "31/12/1830",
#                 "description": "Captains' logs, including: AETNA (1824 May 8-1824 Oct 10). AETNA (1827 Dec 12-1830 Dec 31).",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C4458424",
#                 "title": "Captains' logs, including: AETNA (1778 May 14-1778 Dec 18). AETNA (1779 Aug 25-1780 Jan 16)....",
#                 "startDate": "01/01/1777",
#                 "endDate": "31/12/1785",
#                 "description": "Captains' logs, including: AETNA (1778 May 14-1778 Dec 18). AETNA (1779 Aug 25-1780 Jan 16). AETNA (1780 Dec 28-1781 Dec 5). ARIEL (1777 July 14-1778 Feb 3). ARIEL (1778 Apr 28-1778 Sept 25). ARIEL (1781 Sept 13-1785 Nov 24).",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C4458435",
#                 "title": "Captains' logs, including: AETNA (1840 Jan 1-1842 Apr 25). AETNA (1842 June 11-1844 Mar 11)....",
#                 "startDate": "01/01/1840",
#                 "endDate": "31/12/1849",
#                 "description": "Captains' logs, including: AETNA (1840 Jan 1-1842 Apr 25). AETNA (1842 June 11-1844 Mar 11). ANSON (1843 June 29-1843 Dec 31). ANSON (1844 Jan 30-1844 Apr 24). ASP (1845 Apr 1-1849 Nov 23).",
#                 "reference": "ADM 51"
#             }
#         ]
#     },
#     {
#         "ship": "Africa",
#         "data": [
#             {
#                 "id": "C1497245",
#                 "title": "AFRICA",
#                 "startDate": "01/02/1918",
#                 "endDate": "28/02/1918",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497210",
#                 "title": "AFRICA",
#                 "startDate": "31/03/1914",
#                 "endDate": "28/02/1915",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497240",
#                 "title": "AFRICA",
#                 "startDate": "01/09/1917",
#                 "endDate": "30/09/1917",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497249",
#                 "title": "AFRICA",
#                 "startDate": "01/06/1918",
#                 "endDate": "30/06/1918",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497225",
#                 "title": "AFRICA",
#                 "startDate": "01/05/1916",
#                 "endDate": "31/05/1916",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497223",
#                 "title": "AFRICA",
#                 "startDate": "01/03/1916",
#                 "endDate": "31/03/1916",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497222",
#                 "title": "AFRICA",
#                 "startDate": "01/02/1916",
#                 "endDate": "29/02/1916",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497215",
#                 "title": "AFRICA",
#                 "startDate": "01/07/1915",
#                 "endDate": "31/07/1915",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497230",
#                 "title": "AFRICA",
#                 "startDate": "01/10/1916",
#                 "endDate": "31/10/1916",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497226",
#                 "title": "AFRICA",
#                 "startDate": "01/06/1916",
#                 "endDate": "30/06/1916",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497236",
#                 "title": "AFRICA",
#                 "startDate": "01/04/1917",
#                 "endDate": "30/04/1917",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1481060",
#                 "title": "AFRICA",
#                 "startDate": "01/02/1911",
#                 "endDate": "24/04/1911",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497246",
#                 "title": "AFRICA",
#                 "startDate": "01/03/1918",
#                 "endDate": "31/03/1918",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497213",
#                 "title": "AFRICA",
#                 "startDate": "01/05/1915",
#                 "endDate": "31/05/1915",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497241",
#                 "title": "AFRICA",
#                 "startDate": "01/10/1917",
#                 "endDate": "31/10/1917",
#                 "description": "AFRICA.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Albion",
#         "data": [
#             {
#                 "id": "C2626188",
#                 "title": "ALBION",
#                 "startDate": "01/01/1843",
#                 "endDate": "31/12/1850",
#                 "description": "ALBION.",
#                 "reference": "ADM 54"
#             },
#             {
#                 "id": "C1481260",
#                 "title": "ALBION",
#                 "startDate": "19/01/1913",
#                 "endDate": "22/04/1913",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1464873",
#                 "title": "Albion",
#                 "startDate": "01/12/1850",
#                 "endDate": "31/05/1851",
#                 "description": "Albion.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1464872",
#                 "title": "Albion",
#                 "startDate": "01/06/1850",
#                 "endDate": "30/11/1850",
#                 "description": "Albion.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476726",
#                 "title": "ALBION",
#                 "startDate": "25/06/1901",
#                 "endDate": "16/06/1902",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497591",
#                 "title": "ALBION",
#                 "startDate": "01/07/1917",
#                 "endDate": "31/07/1917",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497604",
#                 "title": "ALBION",
#                 "startDate": "01/08/1918",
#                 "endDate": "31/08/1918",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497602",
#                 "title": "ALBION",
#                 "startDate": "01/06/1918",
#                 "endDate": "30/06/1918",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497584",
#                 "title": "ALBION",
#                 "startDate": "01/12/1916",
#                 "endDate": "31/12/1916",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497596",
#                 "title": "ALBION",
#                 "startDate": "01/12/1917",
#                 "endDate": "31/12/1917",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497579",
#                 "title": "ALBION",
#                 "startDate": "01/05/1916",
#                 "endDate": "17/05/1916",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497577",
#                 "title": "ALBION",
#                 "startDate": "01/03/1916",
#                 "endDate": "31/03/1916",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497575",
#                 "title": "ALBION",
#                 "startDate": "01/01/1916",
#                 "endDate": "31/01/1916",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497573",
#                 "title": "ALBION",
#                 "startDate": "01/11/1915",
#                 "endDate": "30/11/1915",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1497583",
#                 "title": "ALBION",
#                 "startDate": "01/11/1916",
#                 "endDate": "30/11/1916",
#                 "description": "ALBION.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Alceste",
#         "data": [
#             {
#                 "id": "C6224068",
#                 "title": "Alceste",
#                 "startDate": "01/06/1814",
#                 "endDate": "24/09/1815",
#                 "description": "Alceste.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C2530063",
#                 "title": "Masters' logs, including: Alceste (1799 Nov 3 - 1800 Feb 26). Alceste (1801 Aug 8...",
#                 "startDate": "01/01/1799",
#                 "endDate": "31/12/1802",
#                 "description": "Masters' logs, including: Alceste (1799 Nov 3 - 1800 Feb 26). Alceste (1801 Aug 8 - 1802 Apr 15). Alexandria (1801 Sept 12 - 1802 Apr 30).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C4458577",
#                 "title": "Captains' logs, including: ALCESTE (1807 Apr 3-1808 Apr 30). ALCESTE (1809 May 1-1811 June 7)....",
#                 "startDate": "01/01/1807",
#                 "endDate": "31/12/1817",
#                 "description": "Captains' logs, including: ALCESTE (1807 Apr 3-1808 Apr 30). ALCESTE (1809 May 1-1811 June 7). ALCESTE (1811 July 6-1812 June 6). ALCESTE (1812 July 2-1812 Aug 23). ALCESTE (1814 June 1-1817 Feb 18).",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C2530052",
#                 "title": "Masters' logs, including: Albion (1813 Mar 18 - 1814 Jan 30). Alceste (1809 Feb 19...",
#                 "startDate": "01/01/1808",
#                 "endDate": "31/12/1815",
#                 "description": "Masters' logs, including: Albion (1813 Mar 18 - 1814 Jan 30). Alceste (1809 Feb 19 - 1810 Nov 5). Alceste (1811 Mar 3 - 1812 Sept 30). Alceste (1815 May 31 - 1815 Dec 12). Alert (1808 Mar 26 - 1810 Mar 13). Alert (1815 Aug 25 - 1815 Oct 20).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2529872",
#                 "title": "Masters' logs, including: Achille (1806 Jan 20 - 1808 Nov 30). Acorn (1808 Apr 9...",
#                 "startDate": "01/01/1805",
#                 "endDate": "31/12/1808",
#                 "description": "Masters' logs, including: Achille (1806 Jan 20 - 1808 Nov 30). Acorn (1808 Apr 9 - 1808 Oct 8). Alceste (1808 Apr 6 - 1808 Oct 6). Arrow (1807 Apr 27 - 1807 Oct 26). Assistance (1805 Oct 1 - 1806 Sept 30). Audacious (1806 Nov 1 - 1808 Mar 28).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C4458557",
#                 "title": "Captains' logs, including: ALBION (1770 Sept 21-1771 Sept 30). ALBION (1793 Oct 27-1794 Mar 9)....",
#                 "startDate": "01/01/1770",
#                 "endDate": "31/12/1818",
#                 "description": "Captains' logs, including: ALBION (1770 Sept 21-1771 Sept 30). ALBION (1793 Oct 27-1794 Mar 9). ALBION (1794 Mar 24-1795 Mar 19). ALCESTE (1801 July 31-1802 Apr 15). ALCIDE (1793 Sept 9-1794 Dec 7). ALCMENE (1797 Nov 13-1799 Mar 7). ALCMENE (1808 Jan 1-1808 Aug 10). ALERT (1806 Aug 1-1807 July 31). ALEXANDER (1818 Nov 8-1818 Dec 17). ALEXANDRIA (1806 Mar 1-1807 Feb 28).",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C4458320",
#                 "title": "Captains' logs, including: ACHILLE (1799 Feb 27-1800 Feb 26). AGINCOURT (1799 Feb 5-1800 May 22)....",
#                 "startDate": "01/01/1798",
#                 "endDate": "31/12/1800",
#                 "description": "Captains' logs, including: ACHILLE (1799 Feb 27-1800 Feb 26). AGINCOURT (1799 Feb 5-1800 May 22). ALCESTE (1799 July 11-1800 Jan 27). BARFLEUR (1799 June 14-1799 Aug 21). CENTAUR (1799 Apr 1-1800 Mar 31). DROMEDARY (1799 Apr 21-1799 May 5). DRUID (1799 Mar 4-1800 Mar 3). EXPEDITION (1798 June 4-1800 Jan 18). NAIADE (1799 Mar 25-1799 Dec 11). ROYAL OAK (1799 Jan 8-1800 Jan 7). STORK (1799 July 1-1799 Dec 12). VOLAGE (1799 May 1-1799 Aug 3).",
#                 "reference": "ADM 51"
#             }
#         ]
#     },
#     {
#         "ship": "Anaconda",
#         "data": [
#             {
#                 "id": "C2530166",
#                 "title": "Masters' logs, including: Amphion (1810 Oct 4 - 1811 Jan 16). Amphion (1813 July 3...",
#                 "startDate": "01/01/1808",
#                 "endDate": "31/12/1815",
#                 "description": "Masters' logs, including: Amphion (1810 Oct 4 - 1811 Jan 16). Amphion (1813 July 3 - 1814 Dec 31). Anaconda (1813 Nov 27 - 1815 Apr 22). Anholt (1814 June 23 - 1814 Oct 11). Antelope (1808 Dec 10 - 1811 Nov 8).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C4458527",
#                 "title": "Captains' logs, including: ALARM (1811 Feb 13-1811 Oct 13). AMBOYNA (1796 Nov 20-1799 Aug 9)....",
#                 "startDate": "01/01/1796",
#                 "endDate": "31/12/1823",
#                 "description": "Captains' logs, including: ALARM (1811 Feb 13-1811 Oct 13). AMBOYNA (1796 Nov 20-1799 Aug 9). AMSTERDAM (1809 Sept 4-1811 Jan 26). ANACONDA (1813 Nov 20-1815 Apr 21). ANN (Yacht) (1809 Apr 26-1811 Apr 24). ANN (Yacht) (1812 Sept 9-1812 Nov 7). ANN (Yacht) (1812 Nov 23-1812 Dec 29). ANN (Yacht) (1813 Feb 1-1813 Mar 25). APOLLO (1821 Dec 28-1823 May 22).",
#                 "reference": "ADM 51"
#             }
#         ]
#     },
#     {
#         "ship": "Asia",
#         "data": [
#             {
#                 "id": "C1465361",
#                 "title": "Asia",
#                 "startDate": "18/04/1861",
#                 "endDate": "31/03/1862",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465359",
#                 "title": "Asia",
#                 "startDate": "20/02/1851",
#                 "endDate": "24/05/1851",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465358",
#                 "title": "Asia",
#                 "startDate": "22/08/1850",
#                 "endDate": "19/02/1851",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465352",
#                 "title": "Asia",
#                 "startDate": "26/08/1847",
#                 "endDate": "23/02/1848",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476874",
#                 "title": "ASIA",
#                 "startDate": "11/09/1890",
#                 "endDate": "28/10/1891",
#                 "description": "ASIA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476873",
#                 "title": "ASIA",
#                 "startDate": "01/10/1888",
#                 "endDate": "10/09/1890",
#                 "description": "ASIA.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465368",
#                 "title": "Asia",
#                 "startDate": "16/12/1871",
#                 "endDate": "12/12/1872",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465347",
#                 "title": "Asia",
#                 "startDate": "09/10/1826",
#                 "endDate": "05/02/1830",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465380",
#                 "title": "Asia",
#                 "startDate": "01/05/1883",
#                 "endDate": "31/03/1884",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465371",
#                 "title": "Asia",
#                 "startDate": "29/11/1874",
#                 "endDate": "20/11/1875",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465376",
#                 "title": "Asia",
#                 "startDate": "17/04/1879",
#                 "endDate": "31/03/1880",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465375",
#                 "title": "Asia",
#                 "startDate": "09/04/1878",
#                 "endDate": "16/04/1879",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465378",
#                 "title": "Asia",
#                 "startDate": "02/04/1881",
#                 "endDate": "05/04/1882",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465367",
#                 "title": "Asia",
#                 "startDate": "01/01/1871",
#                 "endDate": "15/12/1871",
#                 "description": "Asia.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476871",
#                 "title": "ASIA",
#                 "startDate": "16/03/1886",
#                 "endDate": "27/02/1888",
#                 "description": "ASIA.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Avon",
#         "data": [
#             {
#                 "id": "C2626203",
#                 "title": "AVON",
#                 "startDate": "13/06/1842",
#                 "endDate": "05/04/1849",
#                 "description": "AVON.",
#                 "reference": "ADM 54"
#             },
#             {
#                 "id": "C1498928",
#                 "title": "AVON",
#                 "startDate": "01/06/1914",
#                 "endDate": "31/07/1914",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498935",
#                 "title": "AVON",
#                 "startDate": "01/08/1915",
#                 "endDate": "30/09/1915",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498932",
#                 "title": "AVON",
#                 "startDate": "01/02/1915",
#                 "endDate": "31/03/1915",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498926",
#                 "title": "AVON",
#                 "startDate": "01/02/1914",
#                 "endDate": "31/03/1914",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498925",
#                 "title": "AVON",
#                 "startDate": "01/12/1913",
#                 "endDate": "31/01/1914",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498938",
#                 "title": "AVON",
#                 "startDate": "01/02/1916",
#                 "endDate": "31/03/1916",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498946",
#                 "title": "AVON",
#                 "startDate": "01/02/1918",
#                 "endDate": "31/03/1918",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1498927",
#                 "title": "AVON",
#                 "startDate": "01/04/1914",
#                 "endDate": "31/05/1914",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476932",
#                 "title": "AVON",
#                 "startDate": "01/06/1889",
#                 "endDate": "06/12/1889",
#                 "description": "AVON.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465491",
#                 "title": "Avon",
#                 "startDate": "15/11/1851",
#                 "endDate": "31/12/1851",
#                 "description": "Avon.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465498",
#                 "title": "Avon",
#                 "startDate": "07/01/1855",
#                 "endDate": "07/06/1855",
#                 "description": "Avon.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465488",
#                 "title": "Avon",
#                 "startDate": "07/01/1849",
#                 "endDate": "05/04/1849",
#                 "description": "Avon.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465486",
#                 "title": "Avon",
#                 "startDate": "11/04/1848",
#                 "endDate": "14/08/1848",
#                 "description": "Avon.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465487",
#                 "title": "Avon",
#                 "startDate": "15/08/1848",
#                 "endDate": "06/01/1849",
#                 "description": "Avon.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Bedford",
#         "data": [
#             {
#                 "id": "C1482076",
#                 "title": "BEDFORD",
#                 "startDate": "01/10/1908",
#                 "endDate": "25/03/1909",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1482075",
#                 "title": "BEDFORD",
#                 "startDate": "05/08/1907",
#                 "endDate": "30/09/1908",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1482078",
#                 "title": "BEDFORD",
#                 "startDate": "17/03/1910",
#                 "endDate": "31/08/1910",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1482074",
#                 "title": "BEDFORD",
#                 "startDate": "27/03/1906",
#                 "endDate": "04/08/1907",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1482072",
#                 "title": "BEDFORD",
#                 "startDate": "08/12/1904",
#                 "endDate": "29/11/1905",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1482073",
#                 "title": "BEDFORD",
#                 "startDate": "30/11/1905",
#                 "endDate": "26/03/1906",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1482071",
#                 "title": "BEDFORD",
#                 "startDate": "11/11/1903",
#                 "endDate": "07/12/1904",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C6320274",
#                 "title": "W. Bedford",
#                 "startDate": "02/04/1813",
#                 "endDate": "13/05/1814",
#                 "description": "W. Bedford.",
#                 "reference": "ADM 50"
#             },
#             {
#                 "id": "C1482077",
#                 "title": "BEDFORD",
#                 "startDate": "25/03/1909",
#                 "endDate": "16/03/1910",
#                 "description": "BEDFORD.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C2530408",
#                 "title": "Master's log(s): Bedford",
#                 "startDate": "30/08/1780",
#                 "endDate": "17/07/1783",
#                 "description": "Master's log(s): Bedford.",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2530416",
#                 "title": "Master's log(s): Bedford",
#                 "startDate": "04/11/1807",
#                 "endDate": "05/07/1815",
#                 "description": "Master's log(s): Bedford.",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2530404",
#                 "title": "Master's log(s): Bedford",
#                 "startDate": "07/05/1723",
#                 "endDate": "05/03/1728",
#                 "description": "Master's log(s): Bedford.",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2530407",
#                 "title": "Master's log(s): Bedford",
#                 "startDate": "30/08/1778",
#                 "endDate": "29/08/1780",
#                 "description": "Master's log(s): Bedford.",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2530406",
#                 "title": "Masters' logs, including: Bedford (1757 Mar 1 - 1761 Sept 26). Bedford (1762 July 2...",
#                 "startDate": "01/01/1757",
#                 "endDate": "31/12/1762",
#                 "description": "Masters' logs, including: Bedford (1757 Mar 1 - 1761 Sept 26). Bedford (1762 July 2 - 1762 Dec 20).",
#                 "reference": "ADM 52"
#             },
#             {
#                 "id": "C2530402",
#                 "title": "Masters' logs, including: Bedford (1699 May 5 - 1699 Aug 26). Bedford (1700/1 Mar 6...",
#                 "startDate": "01/01/1692",
#                 "endDate": "31/12/1797",
#                 "description": "Masters' logs, including: Bedford (1699 May 5 - 1699 Aug 26). Bedford (1700/1 Mar 6 - 1702 July 17). Bedford (Galley) (1697 June 28 - 1699/1700 Jan 12). Bideford (1695 Oct 25 - 1698 Nov 4). Bristow (1692 Apr 15 - 1692 Oct 10). Bristow (1693/4 Mar 19 - 1696 Sept 2). Bristow (1697 May 9 - 1797 Oct 11).",
#                 "reference": "ADM 52"
#             }
#         ]
#     },
#     {
#         "ship": "Belle",
#         "data": [
#             {
#                 "id": "C1572178",
#                 "title": "BRIGHTON BELLE",
#                 "startDate": "15/11/1939",
#                 "endDate": "30/11/1939",
#                 "description": "BRIGHTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1511462",
#                 "title": "LONDON BELLE",
#                 "startDate": "04/01/1918",
#                 "endDate": "19/07/1918",
#                 "description": "LONDON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1511459",
#                 "title": "LONDON BELLE",
#                 "startDate": "21/06/1916",
#                 "endDate": "21/08/1916",
#                 "description": "LONDON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1576875",
#                 "title": "LAGUNA BELLE",
#                 "startDate": "06/03/1940",
#                 "endDate": "31/03/1940",
#                 "description": "LAGUNA BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1572179",
#                 "title": "BRIGHTON BELLE",
#                 "startDate": "01/12/1939",
#                 "endDate": "31/12/1939",
#                 "description": "BRIGHTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1575910",
#                 "title": "BRIGHTON BELLE",
#                 "startDate": "01/02/1940",
#                 "endDate": "29/02/1940",
#                 "description": "BRIGHTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1533926",
#                 "title": "CLACTON BELLE.",
#                 "startDate": "28/08/1918",
#                 "endDate": "27/11/1918",
#                 "description": "CLACTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1533927",
#                 "title": "CLACTON BELLE.",
#                 "startDate": "28/11/1918",
#                 "endDate": "04/03/1919",
#                 "description": "CLACTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1511460",
#                 "title": "LONDON BELLE",
#                 "startDate": "24/10/1916",
#                 "endDate": "17/02/1917",
#                 "description": "LONDON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1511458",
#                 "title": "LONDON BELLE",
#                 "startDate": "20/04/1916",
#                 "endDate": "20/06/1916",
#                 "description": "LONDON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1502283",
#                 "title": "CLACTON BELLE",
#                 "startDate": "16/06/1918",
#                 "endDate": "27/08/1918",
#                 "description": "CLACTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1502282",
#                 "title": "CLACTON BELLE",
#                 "startDate": "12/02/1918",
#                 "endDate": "15/06/1918",
#                 "description": "CLACTON BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1576877",
#                 "title": "LAGUNA BELLE",
#                 "startDate": "01/05/1940",
#                 "endDate": "31/05/1940",
#                 "description": "LAGUNA BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1576876",
#                 "title": "LAGUNA BELLE",
#                 "startDate": "01/04/1940",
#                 "endDate": "30/04/1940",
#                 "description": "LAGUNA BELLE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1533928",
#                 "title": "CLACTON BELLE.",
#                 "startDate": "05/03/1919",
#                 "endDate": "03/04/1919",
#                 "description": "CLACTON BELLE.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Belvidera",
#         "data": [
#             {
#                 "id": "C1465741",
#                 "title": "Belvidera",
#                 "startDate": "17/01/1810",
#                 "endDate": "31/10/1812",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465745",
#                 "title": "Belvidera",
#                 "startDate": "30/08/1841",
#                 "endDate": "05/03/1845",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C6224084",
#                 "title": "Belvidera",
#                 "startDate": "29/11/1830",
#                 "endDate": "07/12/1833",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465744",
#                 "title": "Belvidera",
#                 "startDate": "08/12/1833",
#                 "endDate": "19/11/1837",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465742",
#                 "title": "Belvidera",
#                 "startDate": "01/11/1812",
#                 "endDate": "16/10/1814",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465747",
#                 "title": "Belvidera",
#                 "startDate": "13/04/1847",
#                 "endDate": "14/09/1847",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1465746",
#                 "title": "Belvidera",
#                 "startDate": "13/10/1846",
#                 "endDate": "12/04/1847",
#                 "description": "Belvidera.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C4459160",
#                 "title": "Captains' logs: BELVIDERA",
#                 "startDate": "29/11/1830",
#                 "endDate": "02/11/1837",
#                 "description": "Captains' logs: BELVIDERA.",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C4459159",
#                 "title": "Captains' logs: BELVIDERA",
#                 "startDate": "01/01/1810",
#                 "endDate": "20/10/1814",
#                 "description": "Captains' logs: BELVIDERA.",
#                 "reference": "ADM 51"
#             },
#             {
#                 "id": "C4459161",
#                 "title": "Captains' logs, including: BELVIDERA (1841 Aug 30-1843 Sept 30). BELVIDERA (1844 Jan 1-1847 Sept 14)....",
#                 "startDate": "01/01/1839",
#                 "endDate": "31/12/1847",
#                 "description": "Captains' logs, including: BELVIDERA (1841 Aug 30-1843 Sept 30). BELVIDERA (1844 Jan 1-1847 Sept 14). BENBOW (1839 Apr 10-1842 May 23).",
#                 "reference": "ADM 51"
#             }
#         ]
#     },
#     {
#         "ship": "Bold",
#         "data": [
#             {
#                 "id": "C6224087",
#                 "title": "Bold",
#                 "startDate": "31/07/1809",
#                 "endDate": "19/03/1811",
#                 "description": "Bold.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1615090",
#                 "title": "Bold Pathfinder",
#                 "startDate": "01/12/1959",
#                 "endDate": "31/12/1959",
#                 "description": "Bold Pathfinder.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1617259",
#                 "title": "Bold Pathfinder",
#                 "startDate": "01/06/1960",
#                 "endDate": "30/06/1960",
# ...
#                 "endDate": "13/03/1911",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1495935",
#                 "title": "VICTORIOUS",
#                 "startDate": "01/01/1907",
#                 "endDate": "24/08/1908",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1495930",
#                 "title": "VICTORIOUS",
#                 "startDate": "26/04/1902",
#                 "endDate": "17/04/1903",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1632605",
#                 "title": "Victorious",
#                 "startDate": "01/10/1967",
#                 "endDate": "31/10/1967",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1632603",
#                 "title": "Victorious",
#                 "startDate": "01/08/1967",
#                 "endDate": "31/08/1967",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1632601",
#                 "title": "Victorious",
#                 "startDate": "01/06/1967",
#                 "endDate": "30/06/1967",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1632597",
#                 "title": "Victorious",
#                 "startDate": "01/02/1967",
#                 "endDate": "28/02/1967",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1626512",
#                 "title": "Victorious",
#                 "startDate": "01/09/1964",
#                 "endDate": "30/09/1964",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1626510",
#                 "title": "Victorious",
#                 "startDate": "01/07/1964",
#                 "endDate": "31/07/1964",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1625180",
#                 "title": "Victorious",
#                 "startDate": "01/12/1963",
#                 "endDate": "31/12/1963",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1625176",
#                 "title": "Victorious",
#                 "startDate": "01/08/1963",
#                 "endDate": "31/08/1963",
#                 "description": "Victorious.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1593573",
#                 "title": "VICTORIOUS",
#                 "startDate": "01/05/1950",
#                 "endDate": "31/05/1950",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1531756",
#                 "title": "VICTORIOUS",
#                 "startDate": "28/07/1914",
#                 "endDate": "04/02/1915",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1531755",
#                 "title": "VICTORIOUS",
#                 "startDate": "13/07/1914",
#                 "endDate": "28/07/1914",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1531761",
#                 "title": "VICTORIOUS",
#                 "startDate": "13/01/1920",
#                 "endDate": "14/03/1920",
#                 "description": "VICTORIOUS.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Volcano",
#         "data": [
#             {
#                 "id": "C2626503",
#                 "title": "VOLCANO",
#                 "startDate": "18/04/1842",
#                 "endDate": "10/02/1849",
#                 "description": "VOLCANO.",
#                 "reference": "ADM 54"
#             },
#             {
#                 "id": "C1476164",
#                 "title": "Volcano",
#                 "startDate": "19/11/1853",
#                 "endDate": "30/01/1854",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476168",
#                 "title": "Volcano",
#                 "startDate": "22/05/1857",
#                 "endDate": "31/10/1857",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476141",
#                 "title": "Volcano",
#                 "startDate": "26/01/1839",
#                 "endDate": "13/03/1841",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476147",
#                 "title": "Volcano",
#                 "startDate": "08/10/1846",
#                 "endDate": "08/02/1847",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476149",
#                 "title": "Volcano",
#                 "startDate": "14/06/1847",
#                 "endDate": "24/10/1847",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476153",
#                 "title": "Volcano",
#                 "startDate": "01/12/1848",
#                 "endDate": "28/02/1849",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476163",
#                 "title": "Volcano",
#                 "startDate": "26/07/1853",
#                 "endDate": "18/11/1853",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476160",
#                 "title": "Volcano",
#                 "startDate": "30/08/1852",
#                 "endDate": "13/12/1852",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476159",
#                 "title": "Volcano",
#                 "startDate": "27/05/1852",
#                 "endDate": "29/08/1852",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476167",
#                 "title": "Volcano",
#                 "startDate": "25/02/1856",
#                 "endDate": "27/05/1856",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476165",
#                 "title": "Volcano",
#                 "startDate": "19/06/1854",
#                 "endDate": "02/04/1855",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476139",
#                 "title": "Volcano",
#                 "startDate": "28/08/1841",
#                 "endDate": "17/08/1844",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476152",
#                 "title": "Volcano",
#                 "startDate": "19/07/1848",
#                 "endDate": "28/12/1848",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476148",
#                 "title": "Volcano",
#                 "startDate": "09/02/1847",
#                 "endDate": "13/06/1847",
#                 "description": "Volcano.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Whiting",
#         "data": [
#             {
#                 "id": "C1496518",
#                 "title": "WHITING",
#                 "startDate": "01/05/1913",
#                 "endDate": "30/06/1913",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496513",
#                 "title": "WHITING",
#                 "startDate": "01/07/1912",
#                 "endDate": "31/08/1912",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496503",
#                 "title": "WHITING",
#                 "startDate": "01/11/1910",
#                 "endDate": "31/12/1910",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496488",
#                 "title": "WHITING",
#                 "startDate": "15/05/1904",
#                 "endDate": "15/07/1904",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496487",
#                 "title": "WHITING",
#                 "startDate": "16/03/1904",
#                 "endDate": "14/05/1904",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496497",
#                 "title": "WHITING",
#                 "startDate": "01/11/1909",
#                 "endDate": "31/12/1909",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496494",
#                 "title": "WHITING",
#                 "startDate": "01/05/1909",
#                 "endDate": "30/06/1909",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1496493",
#                 "title": "WHITING",
#                 "startDate": "26/02/1909",
#                 "endDate": "30/04/1909",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476392",
#                 "title": "Whiting",
#                 "startDate": "26/01/1856",
#                 "endDate": "16/06/1856",
#                 "description": "Whiting.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1532910",
#                 "title": "WHITING.",
#                 "startDate": "01/07/1918",
#                 "endDate": "31/08/1918",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1532915",
#                 "title": "WHITING.",
#                 "startDate": "01/05/1919",
#                 "endDate": "30/06/1919",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1532904",
#                 "title": "WHITING.",
#                 "startDate": "01/01/1917",
#                 "endDate": "28/02/1917",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1532903",
#                 "title": "WHITING.",
#                 "startDate": "01/11/1916",
#                 "endDate": "31/12/1916",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1476394",
#                 "title": "Whiting",
#                 "startDate": "31/12/1866",
#                 "endDate": "17/07/1868",
#                 "description": "Whiting.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1532906",
#                 "title": "WHITING.",
#                 "startDate": "01/07/1917",
#                 "endDate": "31/08/1917",
#                 "description": "WHITING.",
#                 "reference": "ADM 53"
#             }
#         ]
#     },
#     {
#         "ship": "Wolfe",
#         "data": [
#             {
#                 "id": "C1586823",
#                 "title": "WOLFE",
#                 "startDate": "01/02/1945",
#                 "endDate": "28/02/1945",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1579508",
#                 "title": "WOLFE",
#                 "startDate": "01/07/1941",
#                 "endDate": "31/07/1941",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1585061",
#                 "title": "WOLFE",
#                 "startDate": "01/05/1944",
#                 "endDate": "31/05/1944",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1577774",
#                 "title": "WOLFE",
#                 "startDate": "01/12/1940",
#                 "endDate": "31/12/1940",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1577773",
#                 "title": "WOLFE",
#                 "startDate": "01/11/1940",
#                 "endDate": "30/11/1940",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1587967",
#                 "title": "WOLFE",
#                 "startDate": "01/12/1946",
#                 "endDate": "31/12/1946",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1587965",
#                 "title": "WOLFE",
#                 "startDate": "01/10/1946",
#                 "endDate": "31/10/1946",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1587960",
#                 "title": "WOLFE",
#                 "startDate": "01/05/1946",
#                 "endDate": "31/05/1946",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1587957",
#                 "title": "WOLFE",
#                 "startDate": "01/02/1946",
#                 "endDate": "28/02/1946",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1589637",
#                 "title": "WOLFE",
#                 "startDate": "01/05/1948",
#                 "endDate": "31/05/1948",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1589635",
#                 "title": "WOLFE",
#                 "startDate": "01/03/1948",
#                 "endDate": "31/03/1948",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1589634",
#                 "title": "WOLFE",
#                 "startDate": "01/02/1948",
#                 "endDate": "28/02/1948",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1588748",
#                 "title": "WOLFE",
#                 "startDate": "01/06/1947",
#                 "endDate": "30/06/1947",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1587964",
#                 "title": "WOLFE",
#                 "startDate": "31/08/1946",
#                 "endDate": "30/09/1946",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             },
#             {
#                 "id": "C1587962",
#                 "title": "WOLFE",
#                 "startDate": "01/07/1946",
#                 "endDate": "31/07/1946",
#                 "description": "WOLFE.",
#                 "reference": "ADM 53"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ## Making a useful dataframe

# %% [markdown]
# A dataframe is the equivelent of a single sheet in a spreadsheet, and is the format of data we are going to use when drawing graphs. There are [three rules](https://byuidatascience.github.io/python4ds/tidy-data.html) for a useful and tidy dataframe:
#
# 1. Each variable forms a column
# 2. Each observation forms a row
# 3. Each value is a cell
#
# For the data we have retrieved from Discovery, records act as equivalent to observations, and the variables are the metadata. The data from Discovery is not arranged exactly like this yet; but it is close, and the data structure we created when we ran the requests is going to make it easy to get it into the right structure. We can then perform some checks and modifications to make it easier to work with, such as ensuring that columns are all stored as the correct data type, and checking for missing data.
#
# Note: we are showing one path to get the data into a dataframe, working with data from one endpoint from Discovery. This is a guide, not instructions, so when working with your own data, make sure you think through the steps you are going to take before you start.

# %% [markdown]
# We now have a large JSON file with all the data we want, as a result of the API calls in the previous cell. We also have a good understanding of what a nicely formatted dataframe looks like. The next stage is to use the `pandas` library to convert from the JSON to a dataframe. Doing so allows more powerful interactions with the dataframe, such as specifying the format of a column (e.g. that all values are dates), or filtering to only include rows that match a certain criteria.
#
# The first step we are going to take is to flatten the json. Having a flat json file makes it very straightforwards to convert to a dataframe; each record relates to an item in the json and a row in the dataframe, with each key in the json relating to a column in the dataframe. As with before, it can be valuable to draw the structure of the json to help visualise the result and ensure the conversion runs correctly.

# %% [markdown]
# ```json
# [
#     {
#         "ship": "[ship name]",
#         "id": "[record id]",
#         "title": "[record title]",
#         "startDate": "[record start date]",
#         "endDate": "[record end date]",
#         "description": "[record description]",
#         "reference": "[record reference]"
#     },
#     ...next record
# ]
# ```

# %%
ship_data_flat = []

for ship in ship_data:
    for record in ship["data"]:
        ship_data_flat.append(
            {
                "ship": ship["ship"],
                "id": record["id"],
                "title": record["title"],
                "startDate": record["startDate"],
                "endDate": record["endDate"],
                "description": record["description"],
                "reference": record["reference"]
            }
        )

print(json.dumps(ship_data_flat, indent=4))
# Out:
# [
#     {
#         "ship": "Acasta",
#         "id": "C1496956",
#         "title": "ACASTA",
#         "startDate": "01/09/1918",
#         "endDate": "31/10/1918",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1496944",
#         "title": "ACASTA",
#         "startDate": "08/02/1915",
#         "endDate": "09/04/1915",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1496952",
#         "title": "ACASTA",
#         "startDate": "01/11/1917",
#         "endDate": "02/02/1918",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1496951",
#         "title": "ACASTA",
#         "startDate": "01/05/1917",
#         "endDate": "01/07/1917",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1480967",
#         "title": "ACASTA",
#         "startDate": "01/08/1913",
#         "endDate": "30/09/1913",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1496964",
#         "title": "ACASTA",
#         "startDate": "01/01/1920",
#         "endDate": "29/02/1920",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1558828",
#         "title": "ACASTA",
#         "startDate": "01/10/1935",
#         "endDate": "31/10/1935",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1558821",
#         "title": "ACASTA",
#         "startDate": "01/04/1935",
#         "endDate": "30/04/1935",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1534181",
#         "title": "ACASTA.",
#         "startDate": "01/08/1934",
#         "endDate": "31/08/1934",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1534134",
#         "title": "ACASTA.",
#         "startDate": "14/04/1930",
#         "endDate": "14/06/1930",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1534164",
#         "title": "ACASTA.",
#         "startDate": "01/03/1933",
#         "endDate": "31/03/1933",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1534151",
#         "title": "ACASTA.",
#         "startDate": "01/11/1931",
#         "endDate": "30/11/1931",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1565169",
#         "title": "ACASTA",
#         "startDate": "01/04/1938",
#         "endDate": "30/04/1938",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1565166",
#         "title": "ACASTA",
#         "startDate": "01/07/1937",
#         "endDate": "31/07/1937",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Acasta",
#         "id": "C1565162",
#         "title": "ACASTA",
#         "startDate": "01/03/1937",
#         "endDate": "31/03/1937",
#         "description": "ACASTA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481046",
#         "title": "AEOLUS",
#         "startDate": "09/06/1904",
#         "endDate": "30/05/1905",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481050",
#         "title": "AEOLUS",
#         "startDate": "30/06/1908",
#         "endDate": "01/08/1908",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481047",
#         "title": "AEOLUS",
#         "startDate": "31/05/1905",
#         "endDate": "07/09/1905",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1476643",
#         "title": "AEOLUS",
#         "startDate": "08/01/1895",
#         "endDate": "31/12/1895",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1476641",
#         "title": "AEOLUS",
#         "startDate": "11/07/1893",
#         "endDate": "25/08/1893",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481044",
#         "title": "AEOLUS",
#         "startDate": "16/09/1902",
#         "endDate": "18/06/1903",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481045",
#         "title": "AEOLUS",
#         "startDate": "19/06/1903",
#         "endDate": "08/06/1904",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481049",
#         "title": "AEOLUS",
#         "startDate": "31/08/1906",
#         "endDate": "31/05/1907",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481048",
#         "title": "AEOLUS",
#         "startDate": "08/09/1905",
#         "endDate": "30/08/1906",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481053",
#         "title": "AEOLUS",
#         "startDate": "13/05/1912",
#         "endDate": "30/04/1913",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1476646",
#         "title": "AEOLUS",
#         "startDate": "15/06/1897",
#         "endDate": "04/08/1897",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1476642",
#         "title": "AEOLUS",
#         "startDate": "16/01/1894",
#         "endDate": "07/01/1895",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481054",
#         "title": "AEOLUS",
#         "startDate": "01/05/1913",
#         "endDate": "03/10/1913",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481043",
#         "title": "AEOLUS",
#         "startDate": "16/07/1901",
#         "endDate": "20/08/1901",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aeolus",
#         "id": "C1481042",
#         "title": "AEOLUS",
#         "startDate": "11/07/1899",
#         "endDate": "17/08/1899",
#         "description": "AEOLUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C1464685",
#         "title": "Aetna (Etna)",
#         "startDate": "23/10/1834",
#         "endDate": "31/12/1836",
#         "description": "Aetna (Etna).",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C1464686",
#         "title": "Aetna (Etna)",
#         "startDate": "01/01/1837",
#         "endDate": "13/11/1838",
#         "description": "Aetna (Etna).",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C1464683",
#         "title": "Aetna (Etna)",
#         "startDate": "27/05/1830",
#         "endDate": "10/09/1833",
#         "description": "Aetna (Etna).",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C1464687",
#         "title": "Aetna (Etna)",
#         "startDate": "08/02/1839",
#         "endDate": "25/04/1842",
#         "description": "Aetna (Etna).",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C6224063",
#         "title": "Aetna (Etna)",
#         "startDate": "11/06/1842",
#         "endDate": "11/03/1844",
#         "description": "Aetna (Etna).",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C6224062",
#         "title": "Aetna (Etna)",
#         "startDate": "12/12/1827",
#         "endDate": "24/05/1830",
#         "description": "Aetna (Etna).",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C16604172",
#         "title": "Masters' logs: Aetna",
#         "startDate": "15/03/1836",
#         "endDate": "18/11/1838",
#         "description": "Masters' logs: Aetna.",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C2529962",
#         "title": "Masters' logs, including: Aetna (1778 May 14 - 1779 Feb 26). Aetna (1779 Mar 4...",
#         "startDate": "01/01/1778",
#         "endDate": "31/12/1781",
#         "description": "Masters' logs, including: Aetna (1778 May 14 - 1779 Feb 26). Aetna (1779 Mar 4 - 1779 Aug 29). Aetna (1780 Jan 17 - 1781 Mar 7). Aetna (1781 July 12 - 1781 Dec 5).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C2529963",
#         "title": "Masters' logs, including: Aetna (1804 Jan 4 - 1805 Jan 5). Aetna (1805 Jan 17...",
#         "startDate": "01/01/1801",
#         "endDate": "31/12/1806",
#         "description": "Masters' logs, including: Aetna (1804 Jan 4 - 1805 Jan 5). Aetna (1805 Jan 17 - 1805 May 4). Aetna (1805 Sept 19 - 1806 July 22). Argo (1801 Sept 16 - 1804 Oct 27). Atalante (1803 Jan 14 - 1803 Dec 31). Atalante (1804 Jan 19 - 1805 Aug 21).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C2529961",
#         "title": "Masters' logs, including: Aetna (1756 Dec 16 - 1757 July 31). Aetna (1757 Aug 12...",
#         "startDate": "01/01/1756",
#         "endDate": "31/12/1758",
#         "description": "Masters' logs, including: Aetna (1756 Dec 16 - 1757 July 31). Aetna (1757 Aug 12 - 1758 May 20).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C2529959",
#         "title": "Masters' logs, including: Aetna (1691/2 Feb 22 - 1693 Nov 25). Aetna (1695 June 8...",
#         "startDate": "01/01/1690",
#         "endDate": "31/12/1701",
#         "description": "Masters' logs, including: Aetna (1691/2 Feb 22 - 1693 Nov 25). Aetna (1695 June 8 - 1696 June 27). Eagle (1689/90 Feb 13 - 1695 Nov 19). Eagle (1696 Sept 23 - 1697 Dec 7). Eagle (1697/8 Feb 2 - 1699 May 22). Eagle (1699/1700 Mar 11 - 1700/1 Feb 20).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C4458433",
#         "title": "Captains' logs, including: AETNA (1831 Oct 27-1832 Apr 30). AETNA (1833 Jan 1-1833 Sept 10)....",
#         "startDate": "01/01/1831",
#         "endDate": "31/12/1836",
#         "description": "Captains' logs, including: AETNA (1831 Oct 27-1832 Apr 30). AETNA (1833 Jan 1-1833 Sept 10). AETNA (1833 Dec 24-1836 Sept 30).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C4458431",
#         "title": "Captains' logs, including: AETNA (1824 May 8-1824 Oct 10). AETNA (1827 Dec 12-1830 Dec 31)...",
#         "startDate": "01/01/1824",
#         "endDate": "31/12/1830",
#         "description": "Captains' logs, including: AETNA (1824 May 8-1824 Oct 10). AETNA (1827 Dec 12-1830 Dec 31).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C4458424",
#         "title": "Captains' logs, including: AETNA (1778 May 14-1778 Dec 18). AETNA (1779 Aug 25-1780 Jan 16)....",
#         "startDate": "01/01/1777",
#         "endDate": "31/12/1785",
#         "description": "Captains' logs, including: AETNA (1778 May 14-1778 Dec 18). AETNA (1779 Aug 25-1780 Jan 16). AETNA (1780 Dec 28-1781 Dec 5). ARIEL (1777 July 14-1778 Feb 3). ARIEL (1778 Apr 28-1778 Sept 25). ARIEL (1781 Sept 13-1785 Nov 24).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Aetna",
#         "id": "C4458435",
#         "title": "Captains' logs, including: AETNA (1840 Jan 1-1842 Apr 25). AETNA (1842 June 11-1844 Mar 11)....",
#         "startDate": "01/01/1840",
#         "endDate": "31/12/1849",
#         "description": "Captains' logs, including: AETNA (1840 Jan 1-1842 Apr 25). AETNA (1842 June 11-1844 Mar 11). ANSON (1843 June 29-1843 Dec 31). ANSON (1844 Jan 30-1844 Apr 24). ASP (1845 Apr 1-1849 Nov 23).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497245",
#         "title": "AFRICA",
#         "startDate": "01/02/1918",
#         "endDate": "28/02/1918",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497210",
#         "title": "AFRICA",
#         "startDate": "31/03/1914",
#         "endDate": "28/02/1915",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497240",
#         "title": "AFRICA",
#         "startDate": "01/09/1917",
#         "endDate": "30/09/1917",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497249",
#         "title": "AFRICA",
#         "startDate": "01/06/1918",
#         "endDate": "30/06/1918",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497225",
#         "title": "AFRICA",
#         "startDate": "01/05/1916",
#         "endDate": "31/05/1916",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497223",
#         "title": "AFRICA",
#         "startDate": "01/03/1916",
#         "endDate": "31/03/1916",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497222",
#         "title": "AFRICA",
#         "startDate": "01/02/1916",
#         "endDate": "29/02/1916",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497215",
#         "title": "AFRICA",
#         "startDate": "01/07/1915",
#         "endDate": "31/07/1915",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497230",
#         "title": "AFRICA",
#         "startDate": "01/10/1916",
#         "endDate": "31/10/1916",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497226",
#         "title": "AFRICA",
#         "startDate": "01/06/1916",
#         "endDate": "30/06/1916",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497236",
#         "title": "AFRICA",
#         "startDate": "01/04/1917",
#         "endDate": "30/04/1917",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1481060",
#         "title": "AFRICA",
#         "startDate": "01/02/1911",
#         "endDate": "24/04/1911",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497246",
#         "title": "AFRICA",
#         "startDate": "01/03/1918",
#         "endDate": "31/03/1918",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497213",
#         "title": "AFRICA",
#         "startDate": "01/05/1915",
#         "endDate": "31/05/1915",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Africa",
#         "id": "C1497241",
#         "title": "AFRICA",
#         "startDate": "01/10/1917",
#         "endDate": "31/10/1917",
#         "description": "AFRICA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C2626188",
#         "title": "ALBION",
#         "startDate": "01/01/1843",
#         "endDate": "31/12/1850",
#         "description": "ALBION.",
#         "reference": "ADM 54"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1481260",
#         "title": "ALBION",
#         "startDate": "19/01/1913",
#         "endDate": "22/04/1913",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1464873",
#         "title": "Albion",
#         "startDate": "01/12/1850",
#         "endDate": "31/05/1851",
#         "description": "Albion.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1464872",
#         "title": "Albion",
#         "startDate": "01/06/1850",
#         "endDate": "30/11/1850",
#         "description": "Albion.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1476726",
#         "title": "ALBION",
#         "startDate": "25/06/1901",
#         "endDate": "16/06/1902",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497591",
#         "title": "ALBION",
#         "startDate": "01/07/1917",
#         "endDate": "31/07/1917",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497604",
#         "title": "ALBION",
#         "startDate": "01/08/1918",
#         "endDate": "31/08/1918",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497602",
#         "title": "ALBION",
#         "startDate": "01/06/1918",
#         "endDate": "30/06/1918",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497584",
#         "title": "ALBION",
#         "startDate": "01/12/1916",
#         "endDate": "31/12/1916",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497596",
#         "title": "ALBION",
#         "startDate": "01/12/1917",
#         "endDate": "31/12/1917",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497579",
#         "title": "ALBION",
#         "startDate": "01/05/1916",
#         "endDate": "17/05/1916",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497577",
#         "title": "ALBION",
#         "startDate": "01/03/1916",
#         "endDate": "31/03/1916",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497575",
#         "title": "ALBION",
#         "startDate": "01/01/1916",
#         "endDate": "31/01/1916",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497573",
#         "title": "ALBION",
#         "startDate": "01/11/1915",
#         "endDate": "30/11/1915",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Albion",
#         "id": "C1497583",
#         "title": "ALBION",
#         "startDate": "01/11/1916",
#         "endDate": "30/11/1916",
#         "description": "ALBION.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C6224068",
#         "title": "Alceste",
#         "startDate": "01/06/1814",
#         "endDate": "24/09/1815",
#         "description": "Alceste.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C2530063",
#         "title": "Masters' logs, including: Alceste (1799 Nov 3 - 1800 Feb 26). Alceste (1801 Aug 8...",
#         "startDate": "01/01/1799",
#         "endDate": "31/12/1802",
#         "description": "Masters' logs, including: Alceste (1799 Nov 3 - 1800 Feb 26). Alceste (1801 Aug 8 - 1802 Apr 15). Alexandria (1801 Sept 12 - 1802 Apr 30).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C4458577",
#         "title": "Captains' logs, including: ALCESTE (1807 Apr 3-1808 Apr 30). ALCESTE (1809 May 1-1811 June 7)....",
#         "startDate": "01/01/1807",
#         "endDate": "31/12/1817",
#         "description": "Captains' logs, including: ALCESTE (1807 Apr 3-1808 Apr 30). ALCESTE (1809 May 1-1811 June 7). ALCESTE (1811 July 6-1812 June 6). ALCESTE (1812 July 2-1812 Aug 23). ALCESTE (1814 June 1-1817 Feb 18).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C2530052",
#         "title": "Masters' logs, including: Albion (1813 Mar 18 - 1814 Jan 30). Alceste (1809 Feb 19...",
#         "startDate": "01/01/1808",
#         "endDate": "31/12/1815",
#         "description": "Masters' logs, including: Albion (1813 Mar 18 - 1814 Jan 30). Alceste (1809 Feb 19 - 1810 Nov 5). Alceste (1811 Mar 3 - 1812 Sept 30). Alceste (1815 May 31 - 1815 Dec 12). Alert (1808 Mar 26 - 1810 Mar 13). Alert (1815 Aug 25 - 1815 Oct 20).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C2529872",
#         "title": "Masters' logs, including: Achille (1806 Jan 20 - 1808 Nov 30). Acorn (1808 Apr 9...",
#         "startDate": "01/01/1805",
#         "endDate": "31/12/1808",
#         "description": "Masters' logs, including: Achille (1806 Jan 20 - 1808 Nov 30). Acorn (1808 Apr 9 - 1808 Oct 8). Alceste (1808 Apr 6 - 1808 Oct 6). Arrow (1807 Apr 27 - 1807 Oct 26). Assistance (1805 Oct 1 - 1806 Sept 30). Audacious (1806 Nov 1 - 1808 Mar 28).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C4458557",
#         "title": "Captains' logs, including: ALBION (1770 Sept 21-1771 Sept 30). ALBION (1793 Oct 27-1794 Mar 9)....",
#         "startDate": "01/01/1770",
#         "endDate": "31/12/1818",
#         "description": "Captains' logs, including: ALBION (1770 Sept 21-1771 Sept 30). ALBION (1793 Oct 27-1794 Mar 9). ALBION (1794 Mar 24-1795 Mar 19). ALCESTE (1801 July 31-1802 Apr 15). ALCIDE (1793 Sept 9-1794 Dec 7). ALCMENE (1797 Nov 13-1799 Mar 7). ALCMENE (1808 Jan 1-1808 Aug 10). ALERT (1806 Aug 1-1807 July 31). ALEXANDER (1818 Nov 8-1818 Dec 17). ALEXANDRIA (1806 Mar 1-1807 Feb 28).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Alceste",
#         "id": "C4458320",
#         "title": "Captains' logs, including: ACHILLE (1799 Feb 27-1800 Feb 26). AGINCOURT (1799 Feb 5-1800 May 22)....",
#         "startDate": "01/01/1798",
#         "endDate": "31/12/1800",
#         "description": "Captains' logs, including: ACHILLE (1799 Feb 27-1800 Feb 26). AGINCOURT (1799 Feb 5-1800 May 22). ALCESTE (1799 July 11-1800 Jan 27). BARFLEUR (1799 June 14-1799 Aug 21). CENTAUR (1799 Apr 1-1800 Mar 31). DROMEDARY (1799 Apr 21-1799 May 5). DRUID (1799 Mar 4-1800 Mar 3). EXPEDITION (1798 June 4-1800 Jan 18). NAIADE (1799 Mar 25-1799 Dec 11). ROYAL OAK (1799 Jan 8-1800 Jan 7). STORK (1799 July 1-1799 Dec 12). VOLAGE (1799 May 1-1799 Aug 3).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Anaconda",
#         "id": "C2530166",
#         "title": "Masters' logs, including: Amphion (1810 Oct 4 - 1811 Jan 16). Amphion (1813 July 3...",
#         "startDate": "01/01/1808",
#         "endDate": "31/12/1815",
#         "description": "Masters' logs, including: Amphion (1810 Oct 4 - 1811 Jan 16). Amphion (1813 July 3 - 1814 Dec 31). Anaconda (1813 Nov 27 - 1815 Apr 22). Anholt (1814 June 23 - 1814 Oct 11). Antelope (1808 Dec 10 - 1811 Nov 8).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Anaconda",
#         "id": "C4458527",
#         "title": "Captains' logs, including: ALARM (1811 Feb 13-1811 Oct 13). AMBOYNA (1796 Nov 20-1799 Aug 9)....",
#         "startDate": "01/01/1796",
#         "endDate": "31/12/1823",
#         "description": "Captains' logs, including: ALARM (1811 Feb 13-1811 Oct 13). AMBOYNA (1796 Nov 20-1799 Aug 9). AMSTERDAM (1809 Sept 4-1811 Jan 26). ANACONDA (1813 Nov 20-1815 Apr 21). ANN (Yacht) (1809 Apr 26-1811 Apr 24). ANN (Yacht) (1812 Sept 9-1812 Nov 7). ANN (Yacht) (1812 Nov 23-1812 Dec 29). ANN (Yacht) (1813 Feb 1-1813 Mar 25). APOLLO (1821 Dec 28-1823 May 22).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465361",
#         "title": "Asia",
#         "startDate": "18/04/1861",
#         "endDate": "31/03/1862",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465359",
#         "title": "Asia",
#         "startDate": "20/02/1851",
#         "endDate": "24/05/1851",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465358",
#         "title": "Asia",
#         "startDate": "22/08/1850",
#         "endDate": "19/02/1851",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465352",
#         "title": "Asia",
#         "startDate": "26/08/1847",
#         "endDate": "23/02/1848",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1476874",
#         "title": "ASIA",
#         "startDate": "11/09/1890",
#         "endDate": "28/10/1891",
#         "description": "ASIA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1476873",
#         "title": "ASIA",
#         "startDate": "01/10/1888",
#         "endDate": "10/09/1890",
#         "description": "ASIA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465368",
#         "title": "Asia",
#         "startDate": "16/12/1871",
#         "endDate": "12/12/1872",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465347",
#         "title": "Asia",
#         "startDate": "09/10/1826",
#         "endDate": "05/02/1830",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465380",
#         "title": "Asia",
#         "startDate": "01/05/1883",
#         "endDate": "31/03/1884",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465371",
#         "title": "Asia",
#         "startDate": "29/11/1874",
#         "endDate": "20/11/1875",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465376",
#         "title": "Asia",
#         "startDate": "17/04/1879",
#         "endDate": "31/03/1880",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465375",
#         "title": "Asia",
#         "startDate": "09/04/1878",
#         "endDate": "16/04/1879",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465378",
#         "title": "Asia",
#         "startDate": "02/04/1881",
#         "endDate": "05/04/1882",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1465367",
#         "title": "Asia",
#         "startDate": "01/01/1871",
#         "endDate": "15/12/1871",
#         "description": "Asia.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Asia",
#         "id": "C1476871",
#         "title": "ASIA",
#         "startDate": "16/03/1886",
#         "endDate": "27/02/1888",
#         "description": "ASIA.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C2626203",
#         "title": "AVON",
#         "startDate": "13/06/1842",
#         "endDate": "05/04/1849",
#         "description": "AVON.",
#         "reference": "ADM 54"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498928",
#         "title": "AVON",
#         "startDate": "01/06/1914",
#         "endDate": "31/07/1914",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498935",
#         "title": "AVON",
#         "startDate": "01/08/1915",
#         "endDate": "30/09/1915",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498932",
#         "title": "AVON",
#         "startDate": "01/02/1915",
#         "endDate": "31/03/1915",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498926",
#         "title": "AVON",
#         "startDate": "01/02/1914",
#         "endDate": "31/03/1914",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498925",
#         "title": "AVON",
#         "startDate": "01/12/1913",
#         "endDate": "31/01/1914",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498938",
#         "title": "AVON",
#         "startDate": "01/02/1916",
#         "endDate": "31/03/1916",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498946",
#         "title": "AVON",
#         "startDate": "01/02/1918",
#         "endDate": "31/03/1918",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1498927",
#         "title": "AVON",
#         "startDate": "01/04/1914",
#         "endDate": "31/05/1914",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1476932",
#         "title": "AVON",
#         "startDate": "01/06/1889",
#         "endDate": "06/12/1889",
#         "description": "AVON.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1465491",
#         "title": "Avon",
#         "startDate": "15/11/1851",
#         "endDate": "31/12/1851",
#         "description": "Avon.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1465498",
#         "title": "Avon",
#         "startDate": "07/01/1855",
#         "endDate": "07/06/1855",
#         "description": "Avon.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1465488",
#         "title": "Avon",
#         "startDate": "07/01/1849",
#         "endDate": "05/04/1849",
#         "description": "Avon.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1465486",
#         "title": "Avon",
#         "startDate": "11/04/1848",
#         "endDate": "14/08/1848",
#         "description": "Avon.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Avon",
#         "id": "C1465487",
#         "title": "Avon",
#         "startDate": "15/08/1848",
#         "endDate": "06/01/1849",
#         "description": "Avon.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482076",
#         "title": "BEDFORD",
#         "startDate": "01/10/1908",
#         "endDate": "25/03/1909",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482075",
#         "title": "BEDFORD",
#         "startDate": "05/08/1907",
#         "endDate": "30/09/1908",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482078",
#         "title": "BEDFORD",
#         "startDate": "17/03/1910",
#         "endDate": "31/08/1910",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482074",
#         "title": "BEDFORD",
#         "startDate": "27/03/1906",
#         "endDate": "04/08/1907",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482072",
#         "title": "BEDFORD",
#         "startDate": "08/12/1904",
#         "endDate": "29/11/1905",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482073",
#         "title": "BEDFORD",
#         "startDate": "30/11/1905",
#         "endDate": "26/03/1906",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482071",
#         "title": "BEDFORD",
#         "startDate": "11/11/1903",
#         "endDate": "07/12/1904",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C6320274",
#         "title": "W. Bedford",
#         "startDate": "02/04/1813",
#         "endDate": "13/05/1814",
#         "description": "W. Bedford.",
#         "reference": "ADM 50"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C1482077",
#         "title": "BEDFORD",
#         "startDate": "25/03/1909",
#         "endDate": "16/03/1910",
#         "description": "BEDFORD.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C2530408",
#         "title": "Master's log(s): Bedford",
#         "startDate": "30/08/1780",
#         "endDate": "17/07/1783",
#         "description": "Master's log(s): Bedford.",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C2530416",
#         "title": "Master's log(s): Bedford",
#         "startDate": "04/11/1807",
#         "endDate": "05/07/1815",
#         "description": "Master's log(s): Bedford.",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C2530404",
#         "title": "Master's log(s): Bedford",
#         "startDate": "07/05/1723",
#         "endDate": "05/03/1728",
#         "description": "Master's log(s): Bedford.",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C2530407",
#         "title": "Master's log(s): Bedford",
#         "startDate": "30/08/1778",
#         "endDate": "29/08/1780",
#         "description": "Master's log(s): Bedford.",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C2530406",
#         "title": "Masters' logs, including: Bedford (1757 Mar 1 - 1761 Sept 26). Bedford (1762 July 2...",
#         "startDate": "01/01/1757",
#         "endDate": "31/12/1762",
#         "description": "Masters' logs, including: Bedford (1757 Mar 1 - 1761 Sept 26). Bedford (1762 July 2 - 1762 Dec 20).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bedford",
#         "id": "C2530402",
#         "title": "Masters' logs, including: Bedford (1699 May 5 - 1699 Aug 26). Bedford (1700/1 Mar 6...",
#         "startDate": "01/01/1692",
#         "endDate": "31/12/1797",
#         "description": "Masters' logs, including: Bedford (1699 May 5 - 1699 Aug 26). Bedford (1700/1 Mar 6 - 1702 July 17). Bedford (Galley) (1697 June 28 - 1699/1700 Jan 12). Bideford (1695 Oct 25 - 1698 Nov 4). Bristow (1692 Apr 15 - 1692 Oct 10). Bristow (1693/4 Mar 19 - 1696 Sept 2). Bristow (1697 May 9 - 1797 Oct 11).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1572178",
#         "title": "BRIGHTON BELLE",
#         "startDate": "15/11/1939",
#         "endDate": "30/11/1939",
#         "description": "BRIGHTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1511462",
#         "title": "LONDON BELLE",
#         "startDate": "04/01/1918",
#         "endDate": "19/07/1918",
#         "description": "LONDON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1511459",
#         "title": "LONDON BELLE",
#         "startDate": "21/06/1916",
#         "endDate": "21/08/1916",
#         "description": "LONDON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1576875",
#         "title": "LAGUNA BELLE",
#         "startDate": "06/03/1940",
#         "endDate": "31/03/1940",
#         "description": "LAGUNA BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1572179",
#         "title": "BRIGHTON BELLE",
#         "startDate": "01/12/1939",
#         "endDate": "31/12/1939",
#         "description": "BRIGHTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1575910",
#         "title": "BRIGHTON BELLE",
#         "startDate": "01/02/1940",
#         "endDate": "29/02/1940",
#         "description": "BRIGHTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1533926",
#         "title": "CLACTON BELLE.",
#         "startDate": "28/08/1918",
#         "endDate": "27/11/1918",
#         "description": "CLACTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1533927",
#         "title": "CLACTON BELLE.",
#         "startDate": "28/11/1918",
#         "endDate": "04/03/1919",
#         "description": "CLACTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1511460",
#         "title": "LONDON BELLE",
#         "startDate": "24/10/1916",
#         "endDate": "17/02/1917",
#         "description": "LONDON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1511458",
#         "title": "LONDON BELLE",
#         "startDate": "20/04/1916",
#         "endDate": "20/06/1916",
#         "description": "LONDON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1502283",
#         "title": "CLACTON BELLE",
#         "startDate": "16/06/1918",
#         "endDate": "27/08/1918",
#         "description": "CLACTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1502282",
#         "title": "CLACTON BELLE",
#         "startDate": "12/02/1918",
#         "endDate": "15/06/1918",
#         "description": "CLACTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1576877",
#         "title": "LAGUNA BELLE",
#         "startDate": "01/05/1940",
#         "endDate": "31/05/1940",
#         "description": "LAGUNA BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1576876",
#         "title": "LAGUNA BELLE",
#         "startDate": "01/04/1940",
#         "endDate": "30/04/1940",
#         "description": "LAGUNA BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belle",
#         "id": "C1533928",
#         "title": "CLACTON BELLE.",
#         "startDate": "05/03/1919",
#         "endDate": "03/04/1919",
#         "description": "CLACTON BELLE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C1465741",
#         "title": "Belvidera",
#         "startDate": "17/01/1810",
#         "endDate": "31/10/1812",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C1465745",
#         "title": "Belvidera",
#         "startDate": "30/08/1841",
#         "endDate": "05/03/1845",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C6224084",
#         "title": "Belvidera",
#         "startDate": "29/11/1830",
#         "endDate": "07/12/1833",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C1465744",
#         "title": "Belvidera",
#         "startDate": "08/12/1833",
#         "endDate": "19/11/1837",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C1465742",
#         "title": "Belvidera",
#         "startDate": "01/11/1812",
#         "endDate": "16/10/1814",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C1465747",
#         "title": "Belvidera",
#         "startDate": "13/04/1847",
#         "endDate": "14/09/1847",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C1465746",
#         "title": "Belvidera",
#         "startDate": "13/10/1846",
#         "endDate": "12/04/1847",
#         "description": "Belvidera.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C4459160",
#         "title": "Captains' logs: BELVIDERA",
#         "startDate": "29/11/1830",
#         "endDate": "02/11/1837",
#         "description": "Captains' logs: BELVIDERA.",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C4459159",
#         "title": "Captains' logs: BELVIDERA",
#         "startDate": "01/01/1810",
#         "endDate": "20/10/1814",
#         "description": "Captains' logs: BELVIDERA.",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Belvidera",
#         "id": "C4459161",
#         "title": "Captains' logs, including: BELVIDERA (1841 Aug 30-1843 Sept 30). BELVIDERA (1844 Jan 1-1847 Sept 14)....",
#         "startDate": "01/01/1839",
#         "endDate": "31/12/1847",
#         "description": "Captains' logs, including: BELVIDERA (1841 Aug 30-1843 Sept 30). BELVIDERA (1844 Jan 1-1847 Sept 14). BENBOW (1839 Apr 10-1842 May 23).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Bold",
#         "id": "C6224087",
#         "title": "Bold",
#         "startDate": "31/07/1809",
#         "endDate": "19/03/1811",
#         "description": "Bold.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1615090",
#         "title": "Bold Pathfinder",
#         "startDate": "01/12/1959",
#         "endDate": "31/12/1959",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1617259",
#         "title": "Bold Pathfinder",
#         "startDate": "01/06/1960",
#         "endDate": "30/06/1960",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1617257",
#         "title": "Bold Pathfinder",
#         "startDate": "01/04/1960",
#         "endDate": "30/04/1960",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1610214",
#         "title": "Bold Pathfinder",
#         "startDate": "01/01/1957",
#         "endDate": "31/01/1957",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1612789",
#         "title": "Bold Pathfinder",
#         "startDate": "01/10/1958",
#         "endDate": "31/10/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1612785",
#         "title": "Bold Pathfinder",
#         "startDate": "01/06/1958",
#         "endDate": "30/06/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1612782",
#         "title": "Bold Pathfinder",
#         "startDate": "01/03/1958",
#         "endDate": "31/03/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1612788",
#         "title": "Bold Pathfinder",
#         "startDate": "01/09/1958",
#         "endDate": "30/09/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1612786",
#         "title": "Bold Pathfinder",
#         "startDate": "01/07/1958",
#         "endDate": "31/07/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1612784",
#         "title": "Bold Pathfinder",
#         "startDate": "01/05/1958",
#         "endDate": "31/05/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1616998",
#         "title": "Bold Pathfinder",
#         "startDate": "01/12/1958",
#         "endDate": "31/12/1958",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1610219",
#         "title": "Bold Pathfinder",
#         "startDate": "01/09/1957",
#         "endDate": "30/09/1957",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1617256",
#         "title": "Bold Pathfinder",
#         "startDate": "01/03/1960",
#         "endDate": "31/03/1960",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bold",
#         "id": "C1617255",
#         "title": "Bold Pathfinder",
#         "startDate": "01/02/1960",
#         "endDate": "29/02/1960",
#         "description": "Bold Pathfinder.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C2530530",
#         "title": "Masters' logs, including: Bonne Citoyenne (1808 Mar 27 - 1810 Mar 16). Bonne Citoyenne (1810...",
#         "startDate": "01/01/1808",
#         "endDate": "31/12/1815",
#         "description": "Masters' logs, including: Bonne Citoyenne (1808 Mar 27 - 1810 Mar 16). Bonne Citoyenne (1810 June 12 - 1815 Feb 28).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C2530529",
#         "title": "Masters' logs, including: Bonne Citoyenne (1797 Aug 10 - 1799 Aug 10). Bonne Citoyenne (1802...",
#         "startDate": "01/01/1797",
#         "endDate": "31/12/1802",
#         "description": "Masters' logs, including: Bonne Citoyenne (1797 Aug 10 - 1799 Aug 10). Bonne Citoyenne (1802 Jan 3 - 1802 Sept 9).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C4459270",
#         "title": "Captains' logs, including: BONNE CITOYENNE (1809 June 18-1809 Nov 27). BONNE CITOYENNE (1809 Dec 9-1815...",
#         "startDate": "01/01/1809",
#         "endDate": "31/12/1815",
#         "description": "Captains' logs, including: BONNE CITOYENNE (1809 June 18-1809 Nov 27). BONNE CITOYENNE (1809 Dec 9-1815 Feb 28).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C4459265",
#         "title": "Captains' logs, including: BONNE CITOYENNE (1799 Oct 5-1802 Sept 8). BONNE CITOYENNE (1808 Mar 26-1808...",
#         "startDate": "01/01/1797",
#         "endDate": "31/12/1808",
#         "description": "Captains' logs, including: BONNE CITOYENNE (1799 Oct 5-1802 Sept 8). BONNE CITOYENNE (1808 Mar 26-1808 Dec 1). BOREAS (1797 Sept 30-1800 Dec 1). BOREAS (1806 Dec 11-1807 Aug 13).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C2530515",
#         "title": "Masters' logs, including: Bombay (1808 Dec 1 - 1811 Sept 18). Bonne Citoyenne (1810 Mar...",
#         "startDate": "01/01/1808",
#         "endDate": "31/12/1811",
#         "description": "Masters' logs, including: Bombay (1808 Dec 1 - 1811 Sept 18). Bonne Citoyenne (1810 Mar 2 - 1810 Sept 1).",
#         "reference": "ADM 52"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C4458864",
#         "title": "Captains' logs, including: ARIADNE (1798 Feb 16-1799 Feb 28). BONNE CITOYENNE (1797 Apr 2-1798 Sept...",
#         "startDate": "01/01/1796",
#         "endDate": "31/12/1799",
#         "description": "Captains' logs, including: ARIADNE (1798 Feb 16-1799 Feb 28). BONNE CITOYENNE (1797 Apr 2-1798 Sept 13). CHAPMAN (1798 May 1-1799 Apr 30). INFLEXIBLE (1798 Apr 28-1799 Apr 27). MERLIN (1796 Apr 28-1798 June 8). RUSSEL (1798 Aug 1-1799 Mar 3). SWIFTSURE (1797 Oct 26-1798 Oct 24).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C4458524",
#         "title": "Captains' logs, including: ALARM (1796 July 15-1797 Aug 5). BONNE CITOYENNE (1796 June 27-1797 Mar...",
#         "startDate": "01/01/1796",
#         "endDate": "31/12/1797",
#         "description": "Captains' logs, including: ALARM (1796 July 15-1797 Aug 5). BONNE CITOYENNE (1796 June 27-1797 Mar 1). BRAAKHEL (1797 Mar 30-1797 Aug 26). CUMBERLAND (1796 Aug 1-1797 May 26). GALATEA (1796 July 1-1797 May 28). HINDOSTAN (1796 Sept 18-1797 July 29). JUSTE (1797 May 9-1797 June 30). MONMOUTH (1796 Sept 11-1797 Aug 20). PALLAS (1796 Jan 28-1797 Jan 27). PROMPTE (1796 Feb 11-1797 July 10). SQUIRREL (1796 June 5-1796 Dec 11). THESEUS (1796 May 5-1797 Feb 6).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Bonne",
#         "id": "C4459268",
#         "title": "Captains' logs, including: BONNE CITOYENNE (1808 Sept 19-1809 Dec 27). DEDAIGNIUSE (1808 Jan 16-1808 May...",
#         "startDate": "01/01/1805",
#         "endDate": "31/12/1809",
# ...
#     },
#     {
#         "ship": "Valiant",
#         "id": "C1552938",
#         "title": "VALIANT",
#         "startDate": "18/01/1924",
#         "endDate": "31/12/1924",
#         "description": "VALIANT.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Valiant",
#         "id": "C1552937",
#         "title": "VALIANT",
#         "startDate": "02/02/1923",
#         "endDate": "17/01/1924",
#         "description": "VALIANT.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C1475793",
#         "title": "Vengeur",
#         "startDate": "09/01/1813",
#         "endDate": "04/07/1815",
#         "description": "Vengeur.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C1475794",
#         "title": "Vengeur",
#         "startDate": "05/07/1815",
#         "endDate": "08/10/1818",
#         "description": "Vengeur.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C1475795",
#         "title": "Vengeur",
#         "startDate": "09/10/1818",
#         "endDate": "07/06/1821",
#         "description": "Vengeur.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C1475792",
#         "title": "Vengeur",
#         "startDate": "01/09/1810",
#         "endDate": "08/01/1813",
#         "description": "Vengeur.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C4462613",
#         "title": "Captains' logs: VENGEUR",
#         "startDate": "01/09/1810",
#         "endDate": "28/04/1815",
#         "description": "Captains' logs: VENGEUR.",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C4462614",
#         "title": "Captains' logs: VENGEUR",
#         "startDate": "29/04/1815",
#         "endDate": "30/09/1819",
#         "description": "Captains' logs: VENGEUR.",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Vengeur",
#         "id": "C4462615",
#         "title": "Captains' logs, including: VENGEUR (1819 Oct 1-1821 June 6). VOLCANO (1837 Jan 1-1838 Apr 17)....",
#         "startDate": "01/01/1819",
#         "endDate": "31/12/1840",
#         "description": "Captains' logs, including: VENGEUR (1819 Oct 1-1821 June 6). VOLCANO (1837 Jan 1-1838 Apr 17). VOLCANO (1838 May 15-1840 Dec 31).",
#         "reference": "ADM 51"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1495938",
#         "title": "VICTORIOUS",
#         "startDate": "22/03/1910",
#         "endDate": "13/03/1911",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1495935",
#         "title": "VICTORIOUS",
#         "startDate": "01/01/1907",
#         "endDate": "24/08/1908",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1495930",
#         "title": "VICTORIOUS",
#         "startDate": "26/04/1902",
#         "endDate": "17/04/1903",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1632605",
#         "title": "Victorious",
#         "startDate": "01/10/1967",
#         "endDate": "31/10/1967",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1632603",
#         "title": "Victorious",
#         "startDate": "01/08/1967",
#         "endDate": "31/08/1967",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1632601",
#         "title": "Victorious",
#         "startDate": "01/06/1967",
#         "endDate": "30/06/1967",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1632597",
#         "title": "Victorious",
#         "startDate": "01/02/1967",
#         "endDate": "28/02/1967",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1626512",
#         "title": "Victorious",
#         "startDate": "01/09/1964",
#         "endDate": "30/09/1964",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1626510",
#         "title": "Victorious",
#         "startDate": "01/07/1964",
#         "endDate": "31/07/1964",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1625180",
#         "title": "Victorious",
#         "startDate": "01/12/1963",
#         "endDate": "31/12/1963",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1625176",
#         "title": "Victorious",
#         "startDate": "01/08/1963",
#         "endDate": "31/08/1963",
#         "description": "Victorious.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1593573",
#         "title": "VICTORIOUS",
#         "startDate": "01/05/1950",
#         "endDate": "31/05/1950",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1531756",
#         "title": "VICTORIOUS",
#         "startDate": "28/07/1914",
#         "endDate": "04/02/1915",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1531755",
#         "title": "VICTORIOUS",
#         "startDate": "13/07/1914",
#         "endDate": "28/07/1914",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Victorious",
#         "id": "C1531761",
#         "title": "VICTORIOUS",
#         "startDate": "13/01/1920",
#         "endDate": "14/03/1920",
#         "description": "VICTORIOUS.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C2626503",
#         "title": "VOLCANO",
#         "startDate": "18/04/1842",
#         "endDate": "10/02/1849",
#         "description": "VOLCANO.",
#         "reference": "ADM 54"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476164",
#         "title": "Volcano",
#         "startDate": "19/11/1853",
#         "endDate": "30/01/1854",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476168",
#         "title": "Volcano",
#         "startDate": "22/05/1857",
#         "endDate": "31/10/1857",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476141",
#         "title": "Volcano",
#         "startDate": "26/01/1839",
#         "endDate": "13/03/1841",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476147",
#         "title": "Volcano",
#         "startDate": "08/10/1846",
#         "endDate": "08/02/1847",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476149",
#         "title": "Volcano",
#         "startDate": "14/06/1847",
#         "endDate": "24/10/1847",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476153",
#         "title": "Volcano",
#         "startDate": "01/12/1848",
#         "endDate": "28/02/1849",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476163",
#         "title": "Volcano",
#         "startDate": "26/07/1853",
#         "endDate": "18/11/1853",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476160",
#         "title": "Volcano",
#         "startDate": "30/08/1852",
#         "endDate": "13/12/1852",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476159",
#         "title": "Volcano",
#         "startDate": "27/05/1852",
#         "endDate": "29/08/1852",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476167",
#         "title": "Volcano",
#         "startDate": "25/02/1856",
#         "endDate": "27/05/1856",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476165",
#         "title": "Volcano",
#         "startDate": "19/06/1854",
#         "endDate": "02/04/1855",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476139",
#         "title": "Volcano",
#         "startDate": "28/08/1841",
#         "endDate": "17/08/1844",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476152",
#         "title": "Volcano",
#         "startDate": "19/07/1848",
#         "endDate": "28/12/1848",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Volcano",
#         "id": "C1476148",
#         "title": "Volcano",
#         "startDate": "09/02/1847",
#         "endDate": "13/06/1847",
#         "description": "Volcano.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496518",
#         "title": "WHITING",
#         "startDate": "01/05/1913",
#         "endDate": "30/06/1913",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496513",
#         "title": "WHITING",
#         "startDate": "01/07/1912",
#         "endDate": "31/08/1912",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496503",
#         "title": "WHITING",
#         "startDate": "01/11/1910",
#         "endDate": "31/12/1910",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496488",
#         "title": "WHITING",
#         "startDate": "15/05/1904",
#         "endDate": "15/07/1904",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496487",
#         "title": "WHITING",
#         "startDate": "16/03/1904",
#         "endDate": "14/05/1904",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496497",
#         "title": "WHITING",
#         "startDate": "01/11/1909",
#         "endDate": "31/12/1909",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496494",
#         "title": "WHITING",
#         "startDate": "01/05/1909",
#         "endDate": "30/06/1909",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1496493",
#         "title": "WHITING",
#         "startDate": "26/02/1909",
#         "endDate": "30/04/1909",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1476392",
#         "title": "Whiting",
#         "startDate": "26/01/1856",
#         "endDate": "16/06/1856",
#         "description": "Whiting.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1532910",
#         "title": "WHITING.",
#         "startDate": "01/07/1918",
#         "endDate": "31/08/1918",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1532915",
#         "title": "WHITING.",
#         "startDate": "01/05/1919",
#         "endDate": "30/06/1919",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1532904",
#         "title": "WHITING.",
#         "startDate": "01/01/1917",
#         "endDate": "28/02/1917",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1532903",
#         "title": "WHITING.",
#         "startDate": "01/11/1916",
#         "endDate": "31/12/1916",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1476394",
#         "title": "Whiting",
#         "startDate": "31/12/1866",
#         "endDate": "17/07/1868",
#         "description": "Whiting.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Whiting",
#         "id": "C1532906",
#         "title": "WHITING.",
#         "startDate": "01/07/1917",
#         "endDate": "31/08/1917",
#         "description": "WHITING.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1586823",
#         "title": "WOLFE",
#         "startDate": "01/02/1945",
#         "endDate": "28/02/1945",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1579508",
#         "title": "WOLFE",
#         "startDate": "01/07/1941",
#         "endDate": "31/07/1941",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1585061",
#         "title": "WOLFE",
#         "startDate": "01/05/1944",
#         "endDate": "31/05/1944",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1577774",
#         "title": "WOLFE",
#         "startDate": "01/12/1940",
#         "endDate": "31/12/1940",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1577773",
#         "title": "WOLFE",
#         "startDate": "01/11/1940",
#         "endDate": "30/11/1940",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1587967",
#         "title": "WOLFE",
#         "startDate": "01/12/1946",
#         "endDate": "31/12/1946",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1587965",
#         "title": "WOLFE",
#         "startDate": "01/10/1946",
#         "endDate": "31/10/1946",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1587960",
#         "title": "WOLFE",
#         "startDate": "01/05/1946",
#         "endDate": "31/05/1946",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1587957",
#         "title": "WOLFE",
#         "startDate": "01/02/1946",
#         "endDate": "28/02/1946",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1589637",
#         "title": "WOLFE",
#         "startDate": "01/05/1948",
#         "endDate": "31/05/1948",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1589635",
#         "title": "WOLFE",
#         "startDate": "01/03/1948",
#         "endDate": "31/03/1948",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1589634",
#         "title": "WOLFE",
#         "startDate": "01/02/1948",
#         "endDate": "28/02/1948",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1588748",
#         "title": "WOLFE",
#         "startDate": "01/06/1947",
#         "endDate": "30/06/1947",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1587964",
#         "title": "WOLFE",
#         "startDate": "31/08/1946",
#         "endDate": "30/09/1946",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     },
#     {
#         "ship": "Wolfe",
#         "id": "C1587962",
#         "title": "WOLFE",
#         "startDate": "01/07/1946",
#         "endDate": "31/07/1946",
#         "description": "WOLFE.",
#         "reference": "ADM 53"
#     }
# ]

# %% [markdown]
# Now that we have our flattened json, pandas makes it easy to convert it to a dataframe, as this next cell shows. We can then print the dataframe to see what it looks like.

# %%
ship_data_frame = pd.DataFrame(ship_data_flat)

print(ship_data_frame)

## write to csv, even if the csv doesn't exist yet

ship_data_frame.to_csv("ship_data.csv")
# Out:
#         ship        id   title   startDate     endDate description reference
# 0     Acasta  C1496956  ACASTA  01/09/1918  31/10/1918     ACASTA.    ADM 53
# 1     Acasta  C1496944  ACASTA  08/02/1915  09/04/1915     ACASTA.    ADM 53
# 2     Acasta  C1496952  ACASTA  01/11/1917  02/02/1918     ACASTA.    ADM 53
# 3     Acasta  C1496951  ACASTA  01/05/1917  01/07/1917     ACASTA.    ADM 53
# 4     Acasta  C1480967  ACASTA  01/08/1913  30/09/1913     ACASTA.    ADM 53
# ...      ...       ...     ...         ...         ...         ...       ...
# 1893   Wolfe  C1589635   WOLFE  01/03/1948  31/03/1948      WOLFE.    ADM 53
# 1894   Wolfe  C1589634   WOLFE  01/02/1948  28/02/1948      WOLFE.    ADM 53
# 1895   Wolfe  C1588748   WOLFE  01/06/1947  30/06/1947      WOLFE.    ADM 53
# 1896   Wolfe  C1587964   WOLFE  31/08/1946  30/09/1946      WOLFE.    ADM 53
# 1897   Wolfe  C1587962   WOLFE  01/07/1946  31/07/1946      WOLFE.    ADM 53
#
# [1898 rows x 7 columns]

# %% [markdown]
# ### Post-dataframe checks and modifications
#
# With the dataframe created, we can now inspect the date columns to ensure they are stored as the correct data type. Doing so will make it easier for us to do things like filtering by date, or calculating the difference between two dates.
#
# With pandas we can refer to a column in a dataframe using `dataframe['column name']`, similar to interacting with a dictionary.

# %%
ship_data_frame["startDate"] = pd.to_datetime(ship_data_frame["startDate"], dayfirst=True)
ship_data_frame["endDate"] = pd.to_datetime(ship_data_frame["endDate"], dayfirst=True)

# %% [markdown]
# Adding a new column is also easy, requiring a very similar syntax. Here, we are going to add a column that calculates the difference between the start and end dates of each record - a step now possible as we have ensured that the dates are stored as the correct data type. We're also going to add a column that maps a colour to each unique ship name, and for each record series, which will make it easier to add colour to the graphs. A final column will number each ship - this one will be useful instead for selecting subsets of data.
#
# We'll finish off these additions by printing the dataframe again, to see what it looks like now.

# %%
ship_data_frame["record_duration"] = ship_data_frame["endDate"] - ship_data_frame["startDate"]

ship_colour_map = {}
for index, ship in enumerate(ship_list):
    ship_colour_map[ship] = f"C{index}"

ship_data_frame["ship_colour"] = ship_data_frame["ship"].map(ship_colour_map)

ship_number_map = {}
for index, ship in enumerate(ship_list):
    ship_number_map[ship] = index

ship_data_frame["ship_number"] = ship_data_frame["ship"].map(ship_number_map)

record_series_colour_map = {}
for index, series in enumerate(ship_data_frame["reference"].unique()):
    record_series_colour_map[series] = f"C{index}"

ship_data_frame["record_series_colour"] = ship_data_frame["reference"].map(record_series_colour_map)

ship_data_frame["description_length"] = ship_data_frame["description"].str.len()

print(ship_data_frame)
# Out:
#         ship        id   title  startDate    endDate description reference  \
# 0     Acasta  C1496956  ACASTA 1918-09-01 1918-10-31     ACASTA.    ADM 53
# 1     Acasta  C1496944  ACASTA 1915-02-08 1915-04-09     ACASTA.    ADM 53
# 2     Acasta  C1496952  ACASTA 1917-11-01 1918-02-02     ACASTA.    ADM 53
# 3     Acasta  C1496951  ACASTA 1917-05-01 1917-07-01     ACASTA.    ADM 53
# 4     Acasta  C1480967  ACASTA 1913-08-01 1913-09-30     ACASTA.    ADM 53
# ...      ...       ...     ...        ...        ...         ...       ...
# 1893   Wolfe  C1589635   WOLFE 1948-03-01 1948-03-31      WOLFE.    ADM 53
# 1894   Wolfe  C1589634   WOLFE 1948-02-01 1948-02-28      WOLFE.    ADM 53
# 1895   Wolfe  C1588748   WOLFE 1947-06-01 1947-06-30      WOLFE.    ADM 53
# 1896   Wolfe  C1587964   WOLFE 1946-08-31 1946-09-30      WOLFE.    ADM 53
# 1897   Wolfe  C1587962   WOLFE 1946-07-01 1946-07-31      WOLFE.    ADM 53
#
#      record_duration ship_colour  ship_number record_series_colour  \
# 0            60 days          C0            0                   C0
# 1            60 days          C0            0                   C0
# 2            93 days          C0            0                   C0
# 3            61 days          C0            0                   C0
# 4            60 days          C0            0                   C0
# ...              ...         ...          ...                  ...
# 1893         30 days        C148          148                   C0
# 1894         27 days        C148          148                   C0
# 1895         29 days        C148          148                   C0
# 1896         30 days        C148          148                   C0
# 1897         30 days        C148          148                   C0
#
#       description_length
# 0                      7
# 1                      7
# 2                      7
# 3                      7
# 4                      7
# ...                  ...
# 1893                   6
# 1894                   6
# 1895                   6
# 1896                   6
# 1897                   6
#
# [1898 rows x 12 columns]

# %% [markdown]
# Checking for missing data is also easy, and can help us to identify any issues with the data. Here, we are going to check for missing data in the description column.

# %%
## check for missing data in the description column

missing_cell_count = ship_data_frame["description"].isna().sum()

print("There are " + str(missing_cell_count) + " missing cells in the description column")
# Out:
# There are 0 missing cells in the description column

# %% [markdown]
# The final thing to do before we move onto the next notebook is to save the dataframe as a csv file. This is a very useful feature of pandas, as it makes the data highly portable - it can be opened in excel or other spreadsheet software, or a different python script (re-opening it with pandas). Here, we are going to use it to let us open the data in the next notebook. Note that the CSV format does not store the data type of each column, so we will need to ensure that we re-apply the data type changes we made in this notebook when we re-open the file.

# %%
## save the dataframe to a csv file

ship_data_frame.to_csv("ship_data.csv")
